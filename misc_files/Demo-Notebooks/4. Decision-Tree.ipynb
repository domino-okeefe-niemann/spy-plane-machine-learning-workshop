# %% [markdown]
# # Decision Tree Example
#
# This notebook uses a sampling of data taken from the Buzzfeed news Github repository on the analysis of surveillance planes found [here](https://github.com/BuzzFeedNews/2016-04-federal-surveillance-planes) and arbitrarily assigned classes.

# %%
# After running this cell to install graphviz, restart the python kernel
# !add-apt-repository universe 
# !apt update
# !apt install -y graphviz
# !pip3 install --user graphviz
# Out:
# zsh:1: command not found: add-apt-repository
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.
#
# The operation couldn’t be completed. Unable to locate a Java Runtime that supports apt.
# Please visit http://www.java.com for information on installing Java.
#
# Requirement already satisfied: graphviz in /Users/okeefniemann/Library/Python/3.11/lib/python/site-packages (0.20.1)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# !brew install graphviz
# Out:
# Running `brew update --auto-update`...
# ==> Auto-updated Homebrew!
# Updated 1 tap (homebrew/core).
# ==> New Formulae
# ast-grep
#
# You have 9 outdated formulae and 1 outdated cask installed.
#
# ==> Fetching dependencies for graphviz: libpng, freetype, fontconfig, jpeg-turbo, giflib, highway, imath, lz4, xz, zstd, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, libavif, gd, glib, jasper, netpbm, gts, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, gdk-pixbuf, fribidi, graphite2, harfbuzz, pango, librsvg, m4 and libtool
# ==> Fetching libpng
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/manifests/1.6.39-1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libpng/blobs/sha256:27fb15928d0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching freetype
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/manifests/2.13.0_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/freetype/blobs/sha256:9dec5b349
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching fontconfig
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/manifests/2.14.2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fontconfig/blobs/sha256:11cd488
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching jpeg-turbo
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/manifests/2.1.5.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-turbo/blobs/sha256:2465718
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching giflib
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/manifests/5.2.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/giflib/blobs/sha256:ced5a24b12f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching highway
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/manifests/1.0.4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/highway/blobs/sha256:bf339bb1c4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching imath
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/manifests/3.1.7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/imath/blobs/sha256:d3cbdbbd65ce
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching lz4
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/manifests/1.9.4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lz4/blobs/sha256:cd29e40287b0a2
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching xz
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/manifests/5.4.3
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xz/blobs/sha256:179cc5316bed5c4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching zstd
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/manifests/1.5.5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/zstd/blobs/sha256:b709835f4cd5d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libtiff
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/manifests/4.5.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtiff/blobs/sha256:cc6d07767e
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching little-cms2
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/manifests/2.14_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/little-cms2/blobs/sha256:6ed3ea
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching openexr
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/manifests/3.1.7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/openexr/blobs/sha256:af3bf3c187
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching webp
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/manifests/1.3.0_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/webp/blobs/sha256:f86256aed05f8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching jpeg-xl
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/manifests/0.8.1_2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jpeg-xl/blobs/sha256:726c44f69d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libvmaf
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/manifests/2.3.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libvmaf/blobs/sha256:ddf3300461
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching aom
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/manifests/3.6.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/aom/blobs/sha256:966c8e8e10fb91
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libavif
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/manifests/0.11.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libavif/blobs/sha256:9b4735a706
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching gd
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/manifests/2.3.3_5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gd/blobs/sha256:3e23180f273c110
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching glib
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/manifests/2.76.2-1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/glib/blobs/sha256:482507b64d76d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching jasper
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/manifests/4.0.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jasper/blobs/sha256:a24af85ebb8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching netpbm
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/manifests/10.86.38_1-1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/netpbm/blobs/sha256:9ff16b71c63
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching gts
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/manifests/0.7.6_2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gts/blobs/sha256:c35739e0ed8143
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching xorgproto
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/manifests/2022.2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/xorgproto/blobs/sha256:d6deb2e4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libxau
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/manifests/1.0.11
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxau/blobs/sha256:d8cc440c580
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libxdmcp
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/manifests/1.1.4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxdmcp/blobs/sha256:2fb2d55b8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libxcb
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/manifests/1.15_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxcb/blobs/sha256:cf7a5932142
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libx11
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/manifests/1.8.4
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libx11/blobs/sha256:e6df4fc6bb8
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libxext
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/manifests/1.3.5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxext/blobs/sha256:36ef533356
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libxrender
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/manifests/0.9.11
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libxrender/blobs/sha256:510d0cd
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching lzo
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/manifests/2.10
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/lzo/blobs/sha256:a565c627b13f2d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching pixman
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/manifests/0.42.2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pixman/blobs/sha256:f98b74948d7
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching cairo
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/manifests/1.16.0_5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cairo/blobs/sha256:4a0f5f55a331
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching gdk-pixbuf
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/manifests/2.42.10_1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/gdk-pixbuf/blobs/sha256:fe74fd0
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching fribidi
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/manifests/1.0.12
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/fribidi/blobs/sha256:98d26d50c4
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching graphite2
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/manifests/1.3.14
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphite2/blobs/sha256:3ec77041
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching harfbuzz
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/manifests/7.3.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/harfbuzz/blobs/sha256:d90cb3296
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching pango
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/manifests/1.50.14
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pango/blobs/sha256:36b5b69c5288
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching librsvg
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/manifests/2.56.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/librsvg/blobs/sha256:91da9830a5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching m4
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/manifests/1.4.19
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/m4/blobs/sha256:11308abe8d607be
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libtool
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/manifests/2.4.7
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libtool/blobs/sha256:924534e0a6
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching graphviz
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/manifests/8.0.5
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/graphviz/blobs/sha256:d9351344f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Installing dependencies for graphviz: libpng, freetype, fontconfig, jpeg-turbo, giflib, highway, imath, lz4, xz, zstd, libtiff, little-cms2, openexr, webp, jpeg-xl, libvmaf, aom, libavif, gd, glib, jasper, netpbm, gts, xorgproto, libxau, libxdmcp, libxcb, libx11, libxext, libxrender, lzo, pixman, cairo, gdk-pixbuf, fribidi, graphite2, harfbuzz, pango, librsvg, m4 and libtool
# ==> Installing graphviz dependency: libpng
# ==> Pouring libpng--1.6.39.arm64_ventura.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/libpng/1.6.39: 27 files, 1.3MB
# ==> Installing graphviz dependency: freetype
# ==> Pouring freetype--2.13.0_1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/freetype/2.13.0_1: 67 files, 2.4MB
# ==> Installing graphviz dependency: fontconfig
# ==> Pouring fontconfig--2.14.2.arm64_ventura.bottle.tar.gz
# ==> Regenerating font cache, this may take a while
# ==> /opt/homebrew/Cellar/fontconfig/2.14.2/bin/fc-cache -frv
# 🍺  /opt/homebrew/Cellar/fontconfig/2.14.2: 88 files, 2.4MB
# ==> Installing graphviz dependency: jpeg-turbo
# ==> Pouring jpeg-turbo--2.1.5.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-turbo/2.1.5.1: 44 files, 2.5MB
# ==> Installing graphviz dependency: giflib
# ==> Pouring giflib--5.2.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/giflib/5.2.1: 19 files, 540.2KB
# ==> Installing graphviz dependency: highway
# ==> Pouring highway--1.0.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/highway/1.0.4: 65 files, 2.6MB
# ==> Installing graphviz dependency: imath
# ==> Pouring imath--3.1.7.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/imath/3.1.7: 49 files, 932.4KB
# ==> Installing graphviz dependency: lz4
# ==> Pouring lz4--1.9.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lz4/1.9.4: 22 files, 680KB
# ==> Installing graphviz dependency: xz
# ==> Pouring xz--5.4.3.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xz/5.4.3: 162 files, 2.6MB
# ==> Installing graphviz dependency: zstd
# ==> Pouring zstd--1.5.5.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/zstd/1.5.5: 31 files, 2.3MB
# ==> Installing graphviz dependency: libtiff
# ==> Pouring libtiff--4.5.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtiff/4.5.0: 474 files, 8.4MB
# ==> Installing graphviz dependency: little-cms2
# ==> Pouring little-cms2--2.14_1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/little-cms2/2.14_1: 21 files, 1.4MB
# ==> Installing graphviz dependency: openexr
# ==> Pouring openexr--3.1.7.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/openexr/3.1.7: 194 files, 6.0MB
# ==> Installing graphviz dependency: webp
# ==> Pouring webp--1.3.0_1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/webp/1.3.0_1: 63 files, 2.3MB
# ==> Installing graphviz dependency: jpeg-xl
# ==> Pouring jpeg-xl--0.8.1_2.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jpeg-xl/0.8.1_2: 43 files, 10.6MB
# ==> Installing graphviz dependency: libvmaf
# ==> Pouring libvmaf--2.3.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libvmaf/2.3.1: 234 files, 7MB
# ==> Installing graphviz dependency: aom
# ==> Pouring aom--3.6.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/aom/3.6.1: 23 files, 8.6MB
# ==> Installing graphviz dependency: libavif
# ==> Pouring libavif--0.11.1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libavif/0.11.1: 19 files, 496.5KB
# ==> Installing graphviz dependency: gd
# ==> Pouring gd--2.3.3_5.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gd/2.3.3_5: 33 files, 1.5MB
# ==> Installing graphviz dependency: glib
# ==> Pouring glib--2.76.2.arm64_ventura.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/glib/2.76.2: 455 files, 22.2MB
# ==> Installing graphviz dependency: jasper
# ==> Pouring jasper--4.0.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/jasper/4.0.0: 44 files, 1.6MB
# ==> Installing graphviz dependency: netpbm
# ==> Pouring netpbm--10.86.38_1.arm64_ventura.bottle.1.tar.gz
# 🍺  /opt/homebrew/Cellar/netpbm/10.86.38_1: 409 files, 18.5MB
# ==> Installing graphviz dependency: gts
# ==> Pouring gts--0.7.6_2.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/gts/0.7.6_2: 25 files, 1.5MB
# ==> Installing graphviz dependency: xorgproto
# ==> Pouring xorgproto--2022.2.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/xorgproto/2022.2: 268 files, 3.9MB
# ==> Installing graphviz dependency: libxau
# ==> Pouring libxau--1.0.11.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxau/1.0.11: 21 files, 123.5KB
# ==> Installing graphviz dependency: libxdmcp
# ==> Pouring libxdmcp--1.1.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxdmcp/1.1.4: 11 files, 130.4KB
# ==> Installing graphviz dependency: libxcb
# ==> Pouring libxcb--1.15_1.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxcb/1.15_1: 2,461 files, 7.3MB
# ==> Installing graphviz dependency: libx11
# ==> Pouring libx11--1.8.4.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libx11/1.8.4: 1,054 files, 7MB
# ==> Installing graphviz dependency: libxext
# ==> Pouring libxext--1.3.5.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxext/1.3.5: 87 files, 445.8KB
# ==> Installing graphviz dependency: libxrender
# ==> Pouring libxrender--0.9.11.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libxrender/0.9.11: 12 files, 213.9KB
# ==> Installing graphviz dependency: lzo
# ==> Pouring lzo--2.10.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/lzo/2.10: 31 files, 566.2KB
# ==> Installing graphviz dependency: pixman
# ==> Pouring pixman--0.42.2.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pixman/0.42.2: 11 files, 842.5KB
# ==> Installing graphviz dependency: cairo
# ==> Pouring cairo--1.16.0_5.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/cairo/1.16.0_5: 126 files, 6.4MB
# ==> Installing graphviz dependency: gdk-pixbuf
# ==> Pouring gdk-pixbuf--2.42.10_1.arm64_ventura.bottle.tar.gz
# ==> /opt/homebrew/Cellar/gdk-pixbuf/2.42.10_1/bin/gdk-pixbuf-query-loaders --upd
# 🍺  /opt/homebrew/Cellar/gdk-pixbuf/2.42.10_1: 150 files, 3.9MB
# ==> Installing graphviz dependency: fribidi
# ==> Pouring fribidi--1.0.12.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/fribidi/1.0.12: 67 files, 662KB
# ==> Installing graphviz dependency: graphite2
# ==> Pouring graphite2--1.3.14.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/graphite2/1.3.14: 18 files, 281.2KB
# ==> Installing graphviz dependency: harfbuzz
# ==> Pouring harfbuzz--7.3.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/harfbuzz/7.3.0: 76 files, 9.2MB
# ==> Installing graphviz dependency: pango
# ==> Pouring pango--1.50.14.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/pango/1.50.14: 68 files, 3.3MB
# ==> Installing graphviz dependency: librsvg
# ==> Pouring librsvg--2.56.0.arm64_ventura.bottle.tar.gz
# ==> /opt/homebrew/opt/gdk-pixbuf/bin/gdk-pixbuf-query-loaders --update-cache
# 🍺  /opt/homebrew/Cellar/librsvg/2.56.0: 22 files, 52.5MB
# ==> Installing graphviz dependency: m4
# ==> Pouring m4--1.4.19.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/m4/1.4.19: 13 files, 742.3KB
# ==> Installing graphviz dependency: libtool
# ==> Pouring libtool--2.4.7.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libtool/2.4.7: 75 files, 3.8MB
# ==> Installing graphviz
# ==> Pouring graphviz--8.0.5.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/graphviz/8.0.5: 283 files, 7MB
# ==> Running `brew cleanup graphviz`...
# Disable this behaviour by setting HOMEBREW_NO_INSTALL_CLEANUP.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ==> Upgrading 2 dependents of upgraded formulae:
# Disable this behaviour by setting HOMEBREW_NO_INSTALLED_DEPENDENTS_CHECK.
# Hide these hints with HOMEBREW_NO_ENV_HINTS (see `man brew`).
# ipython 8.12.0 -> 8.13.2, jupyterlab 3.6.3 -> 4.0.0
# ==> Fetching dependencies for ipython: sqlite
# ==> Fetching sqlite
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/manifests/3.42.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/sqlite/blobs/sha256:c9b11a8dd4f
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching ipython
# ==> Downloading https://ghcr.io/v2/homebrew/core/ipython/manifests/8.13.2
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/ipython/blobs/sha256:8477453c8c
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching dependencies for jupyterlab: pycparser, cffi, libnghttp2, node and python-typing-extensions
# ==> Fetching pycparser
# ==> Downloading https://ghcr.io/v2/homebrew/core/pycparser/manifests/2.21
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/pycparser/blobs/sha256:882d005d
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching cffi
# ==> Downloading https://ghcr.io/v2/homebrew/core/cffi/manifests/1.15.1
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/cffi/blobs/sha256:5971b4b3104b5
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching libnghttp2
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/manifests/1.53.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/libnghttp2/blobs/sha256:e659bf1
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching node
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/manifests/20.1.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/node/blobs/sha256:c81fb67495fcb
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching python-typing-extensions
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-typing-extensions/manife
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/python-typing-extensions/blobs/
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Fetching jupyterlab
# ==> Downloading https://ghcr.io/v2/homebrew/core/jupyterlab/manifests/4.0.0
# ######################################################################### 100.0%
# ==> Downloading https://ghcr.io/v2/homebrew/core/jupyterlab/blobs/sha256:46fd12b
# ==> Downloading from https://pkg-containers.githubusercontent.com/ghcr1/blobs/sh
# ######################################################################### 100.0%
# ==> Upgrading ipython
#   8.12.0 -> 8.13.2
#
# ==> Installing dependencies for ipython: sqlite
# ==> Installing ipython dependency: sqlite
# ==> Pouring sqlite--3.42.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/sqlite/3.42.0: 11 files, 4.5MB
# ==> Installing ipython
# ==> Pouring ipython--8.13.2.arm64_ventura.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /opt/homebrew
# Could not symlink bin/ipython
# Target /opt/homebrew/bin/ipython
# already exists. You may want to remove it:
#   rm '/opt/homebrew/bin/ipython'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite ipython
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run ipython
#
# Possible conflicting files are:
# /opt/homebrew/bin/ipython
# /opt/homebrew/bin/ipython3
# /opt/homebrew/share/man/man1/ipython.1
# ==> Summary
# 🍺  /opt/homebrew/Cellar/ipython/8.13.2: 3,312 files, 19.8MB
# ==> Running `brew cleanup ipython`...
# Removing: /opt/homebrew/Cellar/ipython/8.12.0... (3,706 files, 25.7MB)
# Removing: /Users/okeefniemann/Library/Caches/Homebrew/ipython--8.12.0... (5.1MB)
# ==> Upgrading jupyterlab
#   3.6.3 -> 4.0.0
#
# ==> Installing dependencies for jupyterlab: pycparser, cffi, libnghttp2, node and python-typing-extensions
# ==> Installing jupyterlab dependency: pycparser
# ==> Pouring pycparser--2.21.all.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /opt/homebrew
# Could not symlink lib/python3.11/site-packages/pycparser/__init__.py
# Target /opt/homebrew/lib/python3.11/site-packages/pycparser/__init__.py
# already exists. You may want to remove it:
#   rm '/opt/homebrew/lib/python3.11/site-packages/pycparser/__init__.py'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite pycparser
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run pycparser
#
# Possible conflicting files are:
# /opt/homebrew/lib/python3.11/site-packages/pycparser/__init__.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/_ast_gen.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/_build_tables.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/_c_ast.cfg
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ast_transforms.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/c_ast.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/c_generator.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/c_lexer.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/c_parser.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/lextab.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ply/__init__.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ply/cpp.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ply/ctokens.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ply/lex.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ply/yacc.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/ply/ygen.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/plyparser.py
# /opt/homebrew/lib/python3.11/site-packages/pycparser/yacctab.py
# ==> Summary
# 🍺  /opt/homebrew/Cellar/pycparser/2.21: 46 files, 656.6KB
# ==> Installing jupyterlab dependency: cffi
# ==> Pouring cffi--1.15.1.arm64_ventura.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /opt/homebrew
# Could not symlink lib/python3.11/site-packages/_cffi_backend.cpython-311-darwin.so
# Target /opt/homebrew/lib/python3.11/site-packages/_cffi_backend.cpython-311-darwin.so
# already exists. You may want to remove it:
#   rm '/opt/homebrew/lib/python3.11/site-packages/_cffi_backend.cpython-311-darwin.so'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite cffi
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run cffi
#
# Possible conflicting files are:
# /opt/homebrew/lib/python3.11/site-packages/_cffi_backend.cpython-311-darwin.so
# /opt/homebrew/lib/python3.11/site-packages/cffi/__init__.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/_cffi_errors.h
# /opt/homebrew/lib/python3.11/site-packages/cffi/_cffi_include.h
# /opt/homebrew/lib/python3.11/site-packages/cffi/_embedding.h
# /opt/homebrew/lib/python3.11/site-packages/cffi/api.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/backend_ctypes.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/cffi_opcode.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/commontypes.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/cparser.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/error.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/ffiplatform.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/lock.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/model.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/parse_c_type.h
# /opt/homebrew/lib/python3.11/site-packages/cffi/pkgconfig.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/recompiler.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/setuptools_ext.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/vengine_cpy.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/vengine_gen.py
# /opt/homebrew/lib/python3.11/site-packages/cffi/verifier.py
# ==> Summary
# 🍺  /opt/homebrew/Cellar/cffi/1.15.1: 33 files, 581.1KB
# ==> Installing jupyterlab dependency: libnghttp2
# ==> Pouring libnghttp2--1.53.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/libnghttp2/1.53.0: 13 files, 741.9KB
# ==> Installing jupyterlab dependency: node
# ==> Pouring node--20.1.0.arm64_ventura.bottle.tar.gz
# 🍺  /opt/homebrew/Cellar/node/20.1.0: 2,260 files, 57.3MB
# ==> Installing jupyterlab dependency: python-typing-extensions
# ==> Pouring python-typing-extensions--4.5.0.arm64_ventura.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /opt/homebrew
# Could not symlink lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/INSTALLER
# Target /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/INSTALLER
# already exists. You may want to remove it:
#   rm '/opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/INSTALLER'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite python-typing-extensions
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run python-typing-extensions
#
# Possible conflicting files are:
# /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/INSTALLER
# /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/LICENSE
# /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/METADATA
# /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/RECORD
# /opt/homebrew/lib/python3.11/site-packages/typing_extensions-4.5.0.dist-info/WHEEL
# /opt/homebrew/lib/python3.11/site-packages/typing_extensions.py
# ==> Summary
# 🍺  /opt/homebrew/Cellar/python-typing-extensions/4.5.0: 21 files, 236.2KB
# ==> Installing jupyterlab
# ==> Pouring jupyterlab--4.0.0.arm64_ventura.bottle.tar.gz
# Error: The `brew link` step did not complete successfully
# The formula built, but is not symlinked into /opt/homebrew
# Could not symlink bin/jupyter
# Target /opt/homebrew/bin/jupyter
# already exists. You may want to remove it:
#   rm '/opt/homebrew/bin/jupyter'
#
# To force the link and overwrite all conflicting files:
#   brew link --overwrite jupyterlab
#
# To list all files that would be deleted:
#   brew link --overwrite --dry-run jupyterlab
#
# Possible conflicting files are:
# /opt/homebrew/bin/jupyter
# /opt/homebrew/bin/jupyter-kernel
# /opt/homebrew/bin/jupyter-kernelspec
# /opt/homebrew/bin/jupyter-migrate
# /opt/homebrew/bin/jupyter-run
# /opt/homebrew/bin/jupyter-troubleshoot
# /opt/homebrew/bin/jupyter-trust
# ==> Caveats
# Additional kernels can be installed into the shared jupyter directory
#   /opt/homebrew/etc/jupyter
#
# zsh completions have been installed to:
#   /opt/homebrew/share/zsh/site-functions
# ==> Summary
# 🍺  /opt/homebrew/Cellar/jupyterlab/4.0.0: 6,182 files, 128.3MB
# ==> Running `brew cleanup jupyterlab`...
# Removing: /opt/homebrew/Cellar/jupyterlab/3.6.3... (7,048 files, 149.1MB)
# Removing: /Users/okeefniemann/Library/Caches/Homebrew/jupyterlab--3.6.3... (35.7MB)
# ==> Checking for dependents of upgraded formulae...
# ==> No broken dependents found!
# ==> Caveats
# ==> jupyterlab
# Additional kernels can be installed into the shared jupyter directory
#   /opt/homebrew/etc/jupyter
#
# zsh completions have been installed to:
#   /opt/homebrew/share/zsh/site-functions

# %%
#get the packages we need
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree

from IPython import display
#from sklearn.externals.six import StringIO  
import graphviz

# %%
#read in data
data = pd.read_csv('../data/demo-notebooks-data/simple_example_classes.csv')

# %%
#look at a few rows of data
data.sample(5)

# %%
#look at breakdown of classes
data['class'].value_counts().plot.bar();

# %%
#create the X and y data from our dataset
X = data[['speed', 'altitude']]
y = data['class']

# %%
#split the data into training and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
#create and fit decision tree model
decision_tree_model = DecisionTreeClassifier(max_depth=3).fit(X_train, y_train)

# Generate a plot of the decision tree
columns=list(X_train.columns)
graphviz.Source(tree.export_graphviz(decision_tree_model, out_file=None, feature_names=columns,class_names=True))

# %%
#make predictions on the test data
predictions = decision_tree_model.predict(X_test)

# %%
#create a data frame that compares the real values to the predicted values
test_data = pd.concat([X_test, y_test], axis=1)
test_data['predicted_class'] = predictions
test_data.reset_index(drop=True, inplace=True)
test_data.head()

# %%
test_data[(test_data['speed'] <= 80.5) & (test_data['altitude'] <= 4987)]

# %%
test_data[(test_data['speed'] > 80.5) & (test_data['altitude'] > 4987)]

# %%
#print accuracy score for the test set
decision_tree_model.score(X_test, y_test)
