# %% [markdown]
# # Create and Use model
#
# This notebook pulls in the model from the SpyPlane-OptimizingModel.ipynb notebook and uses that model to train the remaining data
#
# This projects is based off the Buzzfeed news article on identifying spy planes found [here](https://www.buzzfeednews.com/article/peteraldhous/hidden-spy-planes), using the data and code adapted from their github repository [here](https://github.com/BuzzFeedNews/2017-08-spy-plane-finder).

# %%
# %matplotlib inline
#import packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

#sci-kit learn is a library with machine learning algorithms
from sklearn.ensemble import RandomForestClassifier

#package for saving our ML model
import pickle

# %%
#read in data
planes_labeled = pd.read_csv("/mnt/data/planes_labeled.csv")

# %%
#format data by removing non-numeric columnns and factorize the class
X = planes_labeled[['steer1', 'steer2', 'steer4', 'steer5', 'steer6', 'squawk_1', 'altitude3']]
y = pd.factorize(planes_labeled['class'])[0]

# %%
# Create a model based on parameters from the random grid search
np.random.seed(415)
model_tuned = RandomForestClassifier(n_estimators=1100, max_depth=50, max_features='sqrt', 
                               min_samples_split=4, bootstrap=False)

#train model with only features above
model_tuned.fit(X, y)
# Out:
# RandomForestClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=50, max_features='sqrt',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=4,
#                        min_weight_fraction_leaf=0.0, n_estimators=1100,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %% [markdown]
# ### Classify all data
#
# #### Gather and format data
# First we'll remove all of the training data and the known federal planes from the entire data set (which is in the planes_features file.

# %%
#read in all data
feds = pd.read_csv("/mnt/data/feds.csv")
train = pd.read_csv("/mnt/data/train.csv")
planes = pd.read_csv('/mnt/data/planes_features.csv')

# %%
#first gather list of federal plane identifiers to remove
fed_ids = list(feds['adshex'])
len(fed_ids)
# Out:
# 199

# %%
#next gather list of training list identifiers to remove 
remove = fed_ids + list(train['adshex'])
len(remove)
# Out:
# 796

# %%
classify = planes[~planes['adshex'].isin(remove)]

# %%
#look at number of rows and columns in the raw data 
classify.shape
# Out:
# (19160, 33)

# %%
X_all = classify[['steer1', 'steer2', 'steer4', 'steer5', 'steer6', 'squawk_1', 'altitude3']]

# %%
X_all.head()
# Out:
#      steer1    steer2    steer4    steer5    steer6  squawk_1  altitude3
# 0  0.020211  0.048913  0.344090  0.097317  0.186651         0   0.066831
# 1  0.034976  0.048127  0.356314  0.116116  0.159325         0   0.129648
# 3  0.029871  0.044118  0.380515  0.094669  0.182904         0   0.149816
# 4  0.019048  0.049206  0.326984  0.112698  0.206349      1135   0.039683
# 5  0.001582  0.009494  0.416139  0.112342  0.169304      2356   0.178797

# %% [markdown]
# #### Make Predictions
#
# The we'll use our model from the previous section to output those planes that were determined to be potential surveillance plans and join this data with the [FAA aircraft registration database](https://www.faa.gov/licenses_certificates/aircraft_certification/aircraft_registry/releasable_aircraft_download/), which gives the planes’ registration numbers and the organizations they are registered to.|

# %%
real_predictions = model_tuned.predict(X_all)

# %%
#look at number of predicted spy planes
sum(real_predictions)
# Out:
# 282

# %%
#create data frame with only those potential spy planes
candidates = classify[real_predictions == 1]

# %%
candidates.head()
# Out:
#      adshex  duration1  duration2  duration3  duration4  duration5    boxes1  \
# 25   A001FC   0.222222   0.222222   0.222222   0.111111   0.222222  0.222222
# 41   A00324   0.000000   0.000000   0.000000   0.235294   0.764706  0.000000
# 86   A005D8   0.241379   0.137931   0.137931   0.103448   0.379310  0.241379
# 123  A008A4   0.279570   0.112903   0.134409   0.118280   0.354839  0.263441
# 130  A00948   0.090909   0.545455   0.272727   0.090909   0.000000  0.272727
#
#        boxes2    boxes3    boxes4  ...    steer3    steer4    steer5  \
# 25   0.222222  0.111111  0.222222  ...  0.268151  0.292352  0.090029
# 41   0.735294  0.176471  0.029412  ...  0.373111  0.130127  0.091131
# 86   0.068966  0.310345  0.206897  ...  0.335145  0.193823  0.015442
# 123  0.263441  0.284946  0.134409  ...  0.196159  0.243768  0.035043
# 130  0.545455  0.181818  0.000000  ...  0.262551  0.179783  0.090231
#
#        steer6    steer7    steer8  flights  squawk_1  observations     type
# 25   0.141336  0.011617  0.013553        9      7754          1033     BE35
# 41   0.120319  0.004270  0.002393       34      5347         21310     C208
# 86   0.070043  0.007288  0.016553       29      5011          8095  unknown
# 123  0.097058  0.012515  0.025235      186         0         19576     C208
# 130  0.158073  0.010855  0.006106       11         0          1474  unknown
#
# [5 rows x 33 columns]

# %%
#read in FAA data
faa = pd.read_csv("/mnt/data/faa-registration.csv")
faa.head()
# Out:
#   N-NUMBER SERIAL NUMBER MFR MDL CODE  ENG MFR MDL  YEAR MFR  TYPE REGISTRANT  \
# 0        1          1071      3980115      54556.0    1988.0              5.0
# 1      100          5334      7100510      17003.0    1940.0              1.0
# 2    10001           A28      9601202      67007.0    1928.0              1.0
# 3    10002        79-030      8930105      41525.0    1979.0              4.0
# 4    10003             1      056336T          NaN       NaN              1.0
#
#                               NAME                           STREET  \
# 0  FEDERAL AVIATION ADMINISTRATION  WASHINGTON REAGAN NATIONAL ARPT
# 1                      BENE MARY D                       PO BOX 329
# 2                    PERRY AARON O                       PO BOX 736
# 3                     ENGLISH MARK                  655 DOESKIN TRL
# 4               CAMPBELL CHARLES N                   604 CORDOVA CT
#
#                     STREET2         CITY  ... OTHER NAMES(2) OTHER NAMES(3)  \
# 0  3201 THOMAS AVE HANGAR 6   WASHINGTON  ...            NaN            NaN
# 1                       NaN      KETCHUM  ...            NaN            NaN
# 2                       NaN     MULBERRY  ...            NaN            NaN
# 3                       NaN  SANTA MARIA  ...            NaN            NaN
# 4                       NaN    SALISBURY  ...            NaN            NaN
#
#   OTHER NAMES(4)  OTHER NAMES(5) EXPIRATION DATE  UNIQUE ID  KIT MFR  \
# 0            NaN             NaN      20191130.0     524101      NaN
# 1            NaN             NaN      20200430.0     600060      NaN
# 2            NaN             NaN      20190630.0     432072      NaN
# 3            NaN             NaN      20180131.0     831480      NaN
# 4            NaN             NaN      20180331.0    1173853      NaN
#
#   KIT MODEL  MODE S CODE HEX  X35
# 0       NaN           A00001  NaN
# 1       NaN           A004B3  NaN
# 2       NaN           A00726  NaN
# 3       NaN           A00727  NaN
# 4       NaN           A00728  NaN
#
# [5 rows x 35 columns]

# %%
#look at the column names in the FAA registration dataframe
faa.columns
# Out:
# Index(['N-NUMBER', 'SERIAL NUMBER', 'MFR MDL CODE', 'ENG MFR MDL', 'YEAR MFR',
#        'TYPE REGISTRANT', 'NAME', 'STREET', 'STREET2', 'CITY', 'STATE',
#        'ZIP CODE', 'REGION', 'COUNTY', 'COUNTRY', 'LAST ACTION DATE',
#        'CERT ISSUE DATE', 'CERTIFICATION', 'TYPE AIRCRAFT', 'TYPE ENGINE',
#        'STATUS CODE', 'MODE S CODE', 'FRACT OWNER', 'AIR WORTH DATE',
#        'OTHER NAMES(1)', 'OTHER NAMES(2)', 'OTHER NAMES(3)', 'OTHER NAMES(4)',
#        'OTHER NAMES(5)', 'EXPIRATION DATE', 'UNIQUE ID', 'KIT MFR',
#        'KIT MODEL', 'MODE S CODE HEX', 'X35'],
#       dtype='object')

# %%
#seperate out the columns we want to use
plane_info = faa[['N-NUMBER', 'NAME', 'MODE S CODE HEX']].copy()
plane_info.rename(columns = {'N-NUMBER':'n_number', 'NAME':'name', 'MODE S CODE HEX':'adshex'}, inplace = True)

# %%
spy_candidates = candidates.merge(plane_info, on = 'adshex', how = 'left')

# %% [markdown]
# #### Look at predicted probabilities
#
# Here, we'll calculate the probabilities and sort them in descending order.

# %%
#get list of the probabilities
probability_pred = model_tuned.predict_proba(X_all)

# %%
#add the surveillance plane classifications to the data frame and sort
classify_prob = classify.copy()
classify_prob.loc[:,'spy_prob'] = probability_pred[:,1]
classify_prob.sort_values(by = 'spy_prob', ascending=False, inplace=True)

# %%
classify_prob.head()
# Out:
#        adshex  duration1  duration2  duration3  duration4  duration5  \
# 2189   A13098   0.166667   0.166667   0.166667   0.083333   0.416667
# 12218  A7F52E   0.142857   0.095238   0.142857   0.333333   0.285714
# 19689  ADF7A5   0.152778   0.055556   0.125000   0.263889   0.402778
# 86     A005D8   0.241379   0.137931   0.137931   0.103448   0.379310
# 12036  A7D925   0.121212   0.141414   0.070707   0.070707   0.595960
#
#          boxes1    boxes2    boxes3    boxes4  ...    steer4    steer5  \
# 2189   0.250000  0.583333  0.166667  0.000000  ...  0.300802  0.019331
# 12218  0.666667  0.095238  0.238095  0.000000  ...  0.268428  0.009272
# 19689  0.500000  0.444444  0.055556  0.000000  ...  0.078923  0.013625
# 86     0.241379  0.068966  0.310345  0.206897  ...  0.193823  0.015442
# 12036  0.212121  0.515152  0.242424  0.030303  ...  0.096653  0.015661
#
#          steer6    steer7    steer8  flights  squawk_1  observations     type  \
# 2189   0.085809  0.010372  0.028289       12      4415          2121  unknown
# 12218  0.057487  0.012517  0.035234       21      4334          2157  unknown
# 19689  0.051148  0.008070  0.021434       72      4414         19082  unknown
# 86     0.070043  0.007288  0.016553       29      5011          8095  unknown
# 12036  0.047095  0.004015  0.009250       99       230         45079     T206
#
#        spy_prob
# 2189   0.999394
# 12218  0.990909
# 19689  0.986515
# 86     0.979394
# 12036  0.975909
#
# [5 rows x 34 columns]

# %%
#merge with FAA names and registration numbers
classify_prob_faa= classify_prob.merge(plane_info, on = 'adshex', how = 'left')

# %%
#seperate out only those rows with probabilites greater than 0.5 and the relevant columns
relevant_cols = ['adshex', 'type', 'spy_prob', 'n_number', 'name', 'squawk_1', 'steer1', 'steer2', 'steer4', 'steer5', 'steer6', 'altitude3']
candidates_with_prob = classify_prob_faa.loc[classify_prob_faa['spy_prob'] > 0.5, relevant_cols]

# %%
#look at the top 15 results
candidates_with_prob.head(15)
# Out:
#     adshex     type  spy_prob n_number  \
# 0   A13098  unknown  0.999394      NaN
# 1   A7F52E  unknown  0.990909    61122
# 2   ADF7A5  unknown  0.986515      NaN
# 3   A005D8  unknown  0.979394      NaN
# 4   A7D925     T206  0.975909    6045C
# 5   A5DD36     C208  0.961667    477XP
# 6   A657C9     C208  0.943030    508BH
# 7   A954A6     T206  0.940303    700AZ
# 8   ABF404  unknown  0.921818     87AG
# 9   A861A5     B350  0.894545      NaN
# 10  ACCAE3     T206  0.877576    923SD
# 11  A248EE     C206  0.875000    2462G
# 12  A0519F     C501  0.873030     12CV
# 13  A996CB     C208  0.870303    717HP
# 14  A63E52     T206  0.852576    501GW
#
#                                        name  squawk_1    steer1    steer2  \
# 0                                       NaN      4415  0.151344  0.176803
# 1   SRT AVIATION AND TECHNICAL SERVICES INC      4334  0.170144  0.205841
# 2                                       NaN      4414  0.274709  0.310816
# 3                                       NaN      5011  0.105991  0.220630
# 4    ORANGE COUNTY SHERIFFS DEPARTMENT RNSP       230  0.166840  0.315047
# 5                    PARACLETE AVIATION LLC      4444  0.118906  0.183848
# 6                           CITY OF ANAHEIM      4301  0.108156  0.139862
# 7           PIMA COUNTY SHERIFFS DEPARTMENT         0  0.146749  0.153679
# 8              COMMONWEALTH OF PENNSYLVANIA         0  0.123596  0.198502
# 9                                       NaN      4407  0.041726  0.079378
# 10        FRESNO COUNTY SHERIFFS DEPARTMENT         0  0.162198  0.174263
# 11                        WINGED VISION INC         0  0.115905  0.230457
# 12                                 NTSS LLC      4610  0.041874  0.080431
# 13         OHIO DEPARTMENT OF PUBLIC SAFETY         0  0.257457  0.211931
# 14                      CHAPARRAL AIR GROUP      5306  0.207295  0.219210
#
#       steer4    steer5    steer6  altitude3
# 0   0.300802  0.019331  0.085809   0.665724
# 1   0.268428  0.009272  0.057487   0.585999
# 2   0.078923  0.013625  0.051148   0.451473
# 3   0.193823  0.015442  0.070043   0.018653
# 4   0.096653  0.015661  0.047095   0.345793
# 5   0.174916  0.039449  0.124488   0.044846
# 6   0.226881  0.057274  0.146851   0.518197
# 7   0.308205  0.024070  0.089774   0.675872
# 8   0.312734  0.063670  0.050562   0.580524
# 9   0.386335  0.053196  0.175962   0.165157
# 10  0.178284  0.053619  0.136729   0.617962
# 11  0.229139  0.029278  0.076416   0.245681
# 12  0.250829  0.055970  0.252488   0.115257
# 13  0.043956  0.009419  0.087912   0.821036
# 14  0.125471  0.028571  0.075137   0.622492

# %%
#save the spy candidates data frame to a csv file
candidates_with_prob.to_csv("/mnt/data/spy_candidates.csv", index = False)

# %%
#save the confirmed federal surveillance planes with their relevant data to file
feds_data = planes_labeled[planes_labeled['adshex'].isin(fed_ids)]
feds_data = feds_data[['adshex', 'steer1', 'steer2', 'steer4', 'steer5', 'steer6', 'squawk_1', 'altitude3']]
feds_data.to_csv('/mnt/data/feds_data.csv')

# %%
# save the model to disk
file_loc = '/mnt/data/SpyPlane-RandomForest.sav'
pickle.dump(model_tuned, open(file_loc, 'wb'))
